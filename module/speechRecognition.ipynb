# %%
import speech_recognition as sr
from IPython.display import clear_output, display
import time

for index, name in enumerate(sr.Microphone.list_microphone_names()):
    print(f"Microphone #{index}: {name}")
# Out:
# Microphone #0: Microsoft Sound Mapper - Input
# Microphone #1: Microphone (Realtek(R) Audio)
# Microphone #2: Microphone Array (AMD Audio Dev
# Microphone #3: Microsoft Sound Mapper - Output
# Microphone #4: Realtek HD Audio 2nd output (Re
# Microphone #5: Speakers (Realtek(R) Audio)
# Microphone #6: Primary Sound Capture Driver
# Microphone #7: Microphone (Realtek(R) Audio)
# Microphone #8: Microphone Array (AMD Audio Device)
# Microphone #9: Primary Sound Driver
# Microphone #10: Realtek HD Audio 2nd output (Realtek(R) Audio)
# Microphone #11: Speakers (Realtek(R) Audio)
# Microphone #12: Speakers (Realtek(R) Audio)
# Microphone #13: Realtek HD Audio 2nd output (Realtek(R) Audio)
# Microphone #14: Microphone (Realtek(R) Audio)
# Microphone #15: Microphone Array (AMD Audio Device)
# Microphone #16: Stereo Mix (Realtek HD Audio Stereo input)
# Microphone #17: Speakers 1 (Realtek HD Audio output with HAP)
# Microphone #18: Speakers 2 (Realtek HD Audio output with HAP)
# Microphone #19: PC Speaker (Realtek HD Audio output with HAP)
# Microphone #20: Microphone (Realtek HD Audio Mic input)
# Microphone #21: Headphones (Realtek HD Audio 2nd output)
# Microphone #22: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Baseus Bass 15 Clip))
# Microphone #23: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(Baseus Bass 15 Clip))
# Microphone #24: Headphones ()
# Microphone #25: Microphone Array 1 (AMDAfdInstall Wave Microphone - 0)
# Microphone #26: Microphone Array 2 (AMDAfdInstall Wave Microphone - 0)
# Microphone #27: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(X1))
# Microphone #28: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(X1))
# Microphone #29: Headphones ()
# Microphone #30: Headphones ()
# Microphone #31: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(联想thinkplus-TH30))
# Microphone #32: Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(联想thinkplus-TH30))

# %%
recognizer = sr.Recognizer()

# Start using microphone
with sr.Microphone() as source:
    print("Adjusting for ambient noise...")
    recognizer.adjust_for_ambient_noise(source, duration=2)
    print("Listening... Speak now (Interrupt the kernel to stop).\n")

    full_transcript = ""

    try:
        while True:
            print("🎤 Listening...")
            audio = recognizer.listen(source)

            try:
                text = recognizer.recognize_google(audio)
                full_transcript += text + "\n"
                clear_output(wait=True)
                print("📝 Transcribed Text (So far):\n")
                print(full_transcript)

            except sr.UnknownValueError:
                print("❌ Could not understand audio. Try again.\n")
                time.sleep(1)

    except KeyboardInterrupt:
        print("\n🛑 Stopped by user.")
# Out:
# 📝 Transcribed Text (So far):
#
# hello
# hello
# testing
# hi
#
# 🎤 Listening...
# ❌ Could not understand audio. Try again.
#
#
# 🛑 Stopped by user.
